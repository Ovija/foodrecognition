# %%
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
import torch
import albumentations as A
import torchvision.transforms as T
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# !pip install pycocotools
# Out:
# Collecting pycocotools
#   Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.8

# %%
from datasets import load_dataset

dataset = load_dataset("EduardoPacheco/FoodSeg103")
# Out:
# README.md:   0%|          | 0.00/6.71k [00:00<?, ?B/s]
# train-00000-of-00003.parquet:   0%|          | 0.00/351M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/357M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/431M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4983 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2135 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'classes_on_image', 'id'],
#         num_rows: 4983
#     })
#     validation: Dataset({
#         features: ['image', 'label', 'classes_on_image', 'id'],
#         num_rows: 2135
#     })
# })

# %%
from datasets import DatasetDict

# %%
from datasets import DatasetDict

# Define the split ratio (e.g., 80% train, 20% dev)
split_ratio = 0.8

# Split the `train` dataset into new train and dev sets
train_val_split = dataset['train'].train_test_split(test_size=1 - split_ratio)

# Access the newly created splits
new_train_dataset = train_val_split['train']  # 80% of the original train set
new_dev_dataset = train_val_split['test']     # 20% of the original train set

# Now, we have:
# new_train_dataset -> the new train split
# new_dev_dataset -> the new dev split

# If needed, we can create a new DatasetDict that includes the updated train and dev sets
dataset = DatasetDict({
    'train': new_train_dataset,
    'dev': new_dev_dataset,
    'test': dataset['validation']  # Keeping the original validation set
})

# You can now use `updated_dataset_dict` for further processing or save it to disk.

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'classes_on_image', 'id'],
#         num_rows: 3986
#     })
#     dev: Dataset({
#         features: ['image', 'label', 'classes_on_image', 'id'],
#         num_rows: 997
#     })
#     test: Dataset({
#         features: ['image', 'label', 'classes_on_image', 'id'],
#         num_rows: 2135
#     })
# })

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as T
import matplotlib.pyplot as plt
import random
import pandas as pd
import numpy as np
from PIL import Image
import os

# Define data augmentation transformations
train_transforms = T.Compose([
    T.RandomHorizontalFlip(p=0.5),
    T.RandomVerticalFlip(p=0.5),
    T.RandomResizedCrop(size=(512, 512), scale=(0.8, 1.0)),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = T.Compose([
    T.Resize((512, 512)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import numpy as np

def calculate_iou(box1, box2):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.
    box1, box2: [x_min, y_min, x_max, y_max]
    """
    x1_inter = max(box1[0], box2[0])
    y1_inter = max(box1[1], box2[1])
    x2_inter = min(box1[2], box2[2])
    y2_inter = min(box1[3], box2[3])

    inter_area = max(0, x2_inter - x1_inter) * max(0, y2_inter - y1_inter)

    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])

    iou = inter_area / (box1_area + box2_area - inter_area)

    return iou

# %%
def calculate_precision_recall(pred_boxes, pred_labels, pred_scores, gt_boxes, gt_labels, iou_threshold=0.5):
    """
    Calculate precision and recall for a single image.
    pred_boxes: Predicted bounding boxes [x_min, y_min, x_max, y_max]
    pred_labels: Predicted labels
    pred_scores: Confidence scores for predictions
    gt_boxes: Ground truth bounding boxes
    gt_labels: Ground truth labels
    iou_threshold: IoU threshold for a prediction to be considered correct
    """
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    matched_gt = set()

    for i, pred_box in enumerate(pred_boxes):
        pred_label = pred_labels[i]
        pred_score = pred_scores[i]
        
        max_iou = 0
        max_gt_idx = -1

        for j, gt_box in enumerate(gt_boxes):
            if gt_labels[j] == pred_label and j not in matched_gt:
                iou = calculate_iou(pred_box, gt_box)
                if iou > max_iou:
                    max_iou = iou
                    max_gt_idx = j

        if max_iou >= iou_threshold:
            true_positives += 1
            matched_gt.add(max_gt_idx)
        else:
            false_positives += 1

    false_negatives = len(gt_boxes) - len(matched_gt)

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

    return precision, recall

# %%
def calculate_map50(all_precisions):
    """
    Calculate mAP@50 by averaging precision across all images.
    all_precisions: List of precision values for each image
    """
    return np.mean(all_precisions)

# %%
class FoodDataset(Dataset):
    def __init__(self, dataset, transforms=None):
        self.dataset = dataset
        self.transforms = transforms

    def __getitem__(self, idx):
        record = self.dataset[idx]
        
        # Load the image (convert to RGB if needed)
        image = record['image']
        if isinstance(image, str):  # If it's a path to the image, load it
            image = Image.open(image).convert("RGB")
        
        # Load the mask (segmentation mask), convert to a NumPy array
        mask_image = record['label']
        if isinstance(mask_image, str):  # If it's a path, load the mask
            mask_image = Image.open(mask_image).convert('L')  # Grayscale (assuming it's a single-channel mask)
        mask_array = np.array(mask_image)

        # Prepare lists for bounding boxes, labels, and masks
        boxes = []
        labels = []
        masks = []
        
        # Iterate through the class IDs in `classes_on_image`
        for class_id in record['classes_on_image']:
            labels.append(int(class_id))

            # Create a binary mask for the current class ID
            binary_mask = (mask_array == class_id).astype(np.uint8)
            masks.append(torch.tensor(binary_mask, dtype=torch.uint8))

            # Compute the bounding box for the binary mask
            pos = np.where(binary_mask)

            if pos[0].size > 0 and pos[1].size > 0:
                x_min = np.min(pos[1])
                x_max = np.max(pos[1])
                y_min = np.min(pos[0])
                y_max = np.max(pos[0])
                
                # Filter out invalid bounding boxes (width or height == 0)
                if x_min < x_max and y_min < y_max:
                    boxes.append([x_min, y_min, x_max, y_max])
                else:
                    print(f"Skipping invalid box: [{x_min}, {y_min}, {x_max}, {y_max}]")
            else:
                print(f"No valid pixels found for class ID {class_id} in image {record['id']}")

        # Convert lists to tensors
        boxes = torch.tensor(boxes, dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64)
        masks = torch.stack(masks) if masks else torch.empty((0, *image.size[::-1]), dtype=torch.uint8)

        # Create the target dictionary including 'image_id'
        target = {
            'boxes': boxes,
            'labels': labels,
            'masks': masks,
            'image_id': torch.tensor([record['id']])  # Include the 'id' from the record
        }

        # Apply any image transformations (resize, normalize, etc.)
        if self.transforms:
            image = self.transforms(image)

        return image, target

    def __len__(self):
        return len(self.dataset)
# Hyperparameters
lr = 0.0001
weight_decay = 1e-4
batch_size = 4
patience = 5  # Early stopping patience

# Instantiate the dataset and dataloaders with augmentation
train_data = dataset['train']
train_dataset = FoodDataset(train_data, transforms=train_transforms)
val_data = dataset['dev']
dev_dataset = FoodDataset(val_data, transforms=val_transforms)

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
import os
from pycocotools.cocoeval import COCOeval
from pycocotools.coco import COCO 

# Assuming the FoodDataset and other necessary classes are defined as above

# Number of classes in your dataset
num_classes = 104  # Adjust this based on your dataset

# Model setup (e.g., maskrcnn_resnet50_fpn)
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

# Replace the box predictor and mask predictor to match the number of classes
in_features_box = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features_box, num_classes)

in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256  
model.roi_heads.mask_predictor = torchvision.models.detection.mask_rcnn.MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# Move the model to the device (GPU or CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Set up optimizer and learning rate scheduler
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, verbose=True)

# DataLoader for training and validation
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
val_loader = DataLoader(dev_dataset, batch_size=4, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))

# To keep track of the best loss and save the best model
best_val_loss = float('inf')
train_losses, val_losses, class_losses, box_losses, mask_losses = [], [], [], [], []


def evaluate_model(model, data_loader, device, iou_threshold=0.5):
    model.eval()
    all_precisions = []
    all_recalls = []

    with torch.no_grad():
        for images, targets in data_loader:
            images = [img.to(device) for img in images]
            outputs = model(images)

            for i, output in enumerate(outputs):
                pred_boxes = output['boxes'].cpu().numpy()
                pred_scores = output['scores'].cpu().numpy()
                pred_labels = output['labels'].cpu().numpy()

                gt_boxes = targets[i]['boxes'].cpu().numpy()
                gt_labels = targets[i]['labels'].cpu().numpy()

                precision, recall = calculate_precision_recall(pred_boxes, pred_labels, pred_scores, gt_boxes, gt_labels, iou_threshold)
                
                all_precisions.append(precision)
                all_recalls.append(recall)

    mAP50 = calculate_map50(all_precisions)
    avg_precision = np.mean(all_precisions)
    avg_recall = np.mean(all_recalls)

    return mAP50, avg_precision, avg_recall



# Training loop with mAP50, precision, recall evaluation
for epoch in range(30):  # Set high number of epochs
    model.train()
    running_loss = 0.0
    images_processed = 0

    # Training loop
    for images, targets in train_loader:
        images = [image.to(device) for image in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        optimizer.zero_grad()

        # Forward pass (training)
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        losses.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)
        optimizer.step()

        running_loss += losses.item()
        images_processed += len(images)
        
        # Print progress every 100 images
        if images_processed % 100 < len(images):
            print(f"Epoch [{epoch+1}], Processed {images_processed}/{len(train_loader.dataset)} images")


    avg_train_loss = running_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    print(f"Epoch [{epoch+1}], Training Loss: {avg_train_loss}")

    # Validation step
    model.eval()
    val_loss, val_class_loss, val_box_loss, val_mask_loss = 0.0, 0.0, 0.0, 0.0
    
    with torch.no_grad():
        model.train()  # Temporarily switch to training mode to compute loss
        for images, targets in val_loader:
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            # Compute validation losses
            loss_dict = model(images, targets)

            classification_loss = loss_dict['loss_classifier']
            bbox_regression_loss = loss_dict['loss_box_reg']
            mask_loss = loss_dict.get('loss_mask', torch.tensor(0.0))

            total_loss = sum(loss for loss in loss_dict.values())
            val_loss += total_loss.item()
            val_class_loss += classification_loss.item()
            val_box_loss += bbox_regression_loss.item()
            val_mask_loss += mask_loss.item()

        model.eval()  # Switch back to evaluation mode after computing loss

    avg_val_loss = val_loss / len(val_loader)
    avg_val_class_loss = val_class_loss / len(val_loader)
    avg_val_box_loss = val_box_loss / len(val_loader)
    avg_val_mask_loss = val_mask_loss / len(val_loader)

    val_losses.append(avg_val_loss)
    class_losses.append(avg_val_class_loss)
    box_losses.append(avg_val_box_loss)
    mask_losses.append(avg_val_mask_loss)

    print(f"Epoch [{epoch+1}], Validation Loss: {avg_val_loss}")
    print(f"Epoch [{epoch+1}], Validation Class Loss: {avg_val_class_loss}")
    print(f"Epoch [{epoch+1}], Validation Box Loss: {avg_val_box_loss}")
    print(f"Epoch [{epoch+1}], Validation Mask Loss: {avg_val_mask_loss}")

    # Evaluate mAP@50, precision, and recall after each epoch on validation set
    mAP50, avg_precision, avg_recall = evaluate_model(model, val_loader, device)
    print(f"mAP@50: {mAP50}, Precision: {avg_precision}, Recall: {avg_recall}")
    
    # Save checkpoint after each epoch
    checkpoint_path = f"/kaggle/working/model_epoch_{epoch+1}.pth"
    torch.save(model.state_dict(), checkpoint_path)
    print(f"Saved checkpoint for Epoch {epoch+1} at {checkpoint_path}")


    # Early stopping (same as before)
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), "/kaggle/working/best_model.pth")
        print(f"Best model saved at Epoch {epoch+1} with Validation Loss: {best_val_loss}")
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= 5:  # Assuming 5 epochs patience for early stopping
            print(f"Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss}")
            break

    # Step learning rate scheduler
    scheduler.step(avg_val_loss)

# After training is done, visualize the losses
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.plot(class_losses, label='Validation Class Loss')
plt.plot(box_losses, label='Validation Box Loss')
plt.plot(mask_losses, label='Validation Mask Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# Save the loss history to a CSV file
loss_data = pd.DataFrame({
    'epoch': range(1, len(train_losses)+1),
    'train_loss': train_losses,
    'val_loss': val_losses,
    'class_loss': class_losses,
    'box_loss': box_losses,
    'mask_loss': mask_losses
})
loss_data.to_csv('/kaggle/working/loss_history.csv', index=False)
print("Loss history saved to loss_history.csv")
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 170M/170M [00:00<00:00, 217MB/s]
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1], Processed 100/3986 images
# Epoch [1], Processed 200/3986 images
# Epoch [1], Processed 300/3986 images
# Epoch [1], Processed 400/3986 images
# Epoch [1], Processed 500/3986 images
# Epoch [1], Processed 600/3986 images
# Epoch [1], Processed 700/3986 images
# Epoch [1], Processed 800/3986 images
# Epoch [1], Processed 900/3986 images
# Epoch [1], Processed 1000/3986 images
# Epoch [1], Processed 1100/3986 images
# Epoch [1], Processed 1200/3986 images
# Epoch [1], Processed 1300/3986 images
# Epoch [1], Processed 1400/3986 images
# Epoch [1], Processed 1500/3986 images
# Epoch [1], Processed 1600/3986 images
# Epoch [1], Processed 1700/3986 images
# Epoch [1], Processed 1800/3986 images
# Epoch [1], Processed 1900/3986 images
# Epoch [1], Processed 2000/3986 images
# Epoch [1], Processed 2100/3986 images
# Epoch [1], Processed 2200/3986 images
# Epoch [1], Processed 2300/3986 images
# Epoch [1], Processed 2400/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [1], Processed 2500/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [1], Processed 2600/3986 images
# Epoch [1], Processed 2700/3986 images
# Epoch [1], Processed 2800/3986 images
# Epoch [1], Processed 2900/3986 images
# Epoch [1], Processed 3000/3986 images
# Epoch [1], Processed 3100/3986 images
# Epoch [1], Processed 3200/3986 images
# Epoch [1], Processed 3300/3986 images
# Epoch [1], Processed 3400/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [1], Processed 3500/3986 images
# Epoch [1], Processed 3600/3986 images
# Epoch [1], Processed 3700/3986 images
# Epoch [1], Processed 3800/3986 images
# Epoch [1], Processed 3900/3986 images
# Epoch [1], Training Loss: 5.444533188818928
# Epoch [1], Validation Loss: 5.074361205101013
# Epoch [1], Validation Class Loss: 0.4450731731057167
# Epoch [1], Validation Box Loss: 0.25144774307467743
# Epoch [1], Validation Mask Loss: 0.6285718007087707
# mAP@50: 0.015576151809852914, Precision: 0.015576151809852914, Recall: 0.03834957252710512
# Saved checkpoint for Epoch 1 at /kaggle/working/model_epoch_1.pth
# Best model saved at Epoch 1 with Validation Loss: 5.074361205101013
# Epoch [2], Processed 100/3986 images
# Epoch [2], Processed 200/3986 images
# Epoch [2], Processed 300/3986 images
# Epoch [2], Processed 400/3986 images
# Epoch [2], Processed 500/3986 images
# Epoch [2], Processed 600/3986 images
# Epoch [2], Processed 700/3986 images
# Epoch [2], Processed 800/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [2], Processed 900/3986 images
# Epoch [2], Processed 1000/3986 images
# Epoch [2], Processed 1100/3986 images
# Epoch [2], Processed 1200/3986 images
# Epoch [2], Processed 1300/3986 images
# Epoch [2], Processed 1400/3986 images
# Epoch [2], Processed 1500/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [2], Processed 1600/3986 images
# Epoch [2], Processed 1700/3986 images
# Epoch [2], Processed 1800/3986 images
# Epoch [2], Processed 1900/3986 images
# Epoch [2], Processed 2000/3986 images
# Epoch [2], Processed 2100/3986 images
# Epoch [2], Processed 2200/3986 images
# Epoch [2], Processed 2300/3986 images
# Epoch [2], Processed 2400/3986 images
# Epoch [2], Processed 2500/3986 images
# Epoch [2], Processed 2600/3986 images
# Epoch [2], Processed 2700/3986 images
# Epoch [2], Processed 2800/3986 images
# Epoch [2], Processed 2900/3986 images
# Epoch [2], Processed 3000/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [2], Processed 3100/3986 images
# Epoch [2], Processed 3200/3986 images
# Epoch [2], Processed 3300/3986 images
# Epoch [2], Processed 3400/3986 images
# Epoch [2], Processed 3500/3986 images
# Epoch [2], Processed 3600/3986 images
# Epoch [2], Processed 3700/3986 images
# Epoch [2], Processed 3800/3986 images
# Epoch [2], Processed 3900/3986 images
# Epoch [2], Training Loss: 5.032346988513453
# Epoch [2], Validation Loss: 4.969728222370148
# Epoch [2], Validation Class Loss: 0.5089667262434959
# Epoch [2], Validation Box Loss: 0.2889844278127421
# Epoch [2], Validation Mask Loss: 0.6201567962169647
# mAP@50: 0.03245609845409243, Precision: 0.03245609845409243, Recall: 0.04234449379885689
# Saved checkpoint for Epoch 2 at /kaggle/working/model_epoch_2.pth
# Best model saved at Epoch 2 with Validation Loss: 4.969728222370148
# Epoch [3], Processed 100/3986 images
# Epoch [3], Processed 200/3986 images
# Epoch [3], Processed 300/3986 images
# Epoch [3], Processed 400/3986 images
# Epoch [3], Processed 500/3986 images
# Epoch [3], Processed 600/3986 images
# Epoch [3], Processed 700/3986 images
# Epoch [3], Processed 800/3986 images
# Epoch [3], Processed 900/3986 images
# Epoch [3], Processed 1000/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [3], Processed 1100/3986 images
# Epoch [3], Processed 1200/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [3], Processed 1300/3986 images
# Epoch [3], Processed 1400/3986 images
# Epoch [3], Processed 1500/3986 images
# Epoch [3], Processed 1600/3986 images
# Epoch [3], Processed 1700/3986 images
# Epoch [3], Processed 1800/3986 images
# Epoch [3], Processed 1900/3986 images
# Epoch [3], Processed 2000/3986 images
# Epoch [3], Processed 2100/3986 images
# Epoch [3], Processed 2200/3986 images
# Epoch [3], Processed 2300/3986 images
# Epoch [3], Processed 2400/3986 images
# Epoch [3], Processed 2500/3986 images
# Epoch [3], Processed 2600/3986 images
# Epoch [3], Processed 2700/3986 images
# Epoch [3], Processed 2800/3986 images
# Epoch [3], Processed 2900/3986 images
# Epoch [3], Processed 3000/3986 images
# Epoch [3], Processed 3100/3986 images
# Epoch [3], Processed 3200/3986 images
# Epoch [3], Processed 3300/3986 images
# Epoch [3], Processed 3400/3986 images
# Epoch [3], Processed 3500/3986 images
# Epoch [3], Processed 3600/3986 images
# Epoch [3], Processed 3700/3986 images
# Epoch [3], Processed 3800/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [3], Processed 3900/3986 images
# Epoch [3], Training Loss: 4.921916560638872
# Epoch [3], Validation Loss: 4.918108221054077
# Epoch [3], Validation Class Loss: 0.4825874827504158
# Epoch [3], Validation Box Loss: 0.27263543388829564
# Epoch [3], Validation Mask Loss: 0.6175859525203705
# mAP@50: 0.03818439445320086, Precision: 0.03818439445320086, Recall: 0.040887742592857934
# Saved checkpoint for Epoch 3 at /kaggle/working/model_epoch_3.pth
# Best model saved at Epoch 3 with Validation Loss: 4.918108221054077
# Epoch [4], Processed 100/3986 images
# Epoch [4], Processed 200/3986 images
# Epoch [4], Processed 300/3986 images
# Epoch [4], Processed 400/3986 images
# Epoch [4], Processed 500/3986 images
# Epoch [4], Processed 600/3986 images
# Epoch [4], Processed 700/3986 images
# Epoch [4], Processed 800/3986 images
# Epoch [4], Processed 900/3986 images
# Epoch [4], Processed 1000/3986 images
# Epoch [4], Processed 1100/3986 images
# Epoch [4], Processed 1200/3986 images
# Epoch [4], Processed 1300/3986 images
# Epoch [4], Processed 1400/3986 images
# Epoch [4], Processed 1500/3986 images
# Epoch [4], Processed 1600/3986 images
# Epoch [4], Processed 1700/3986 images
# Epoch [4], Processed 1800/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [4], Processed 1900/3986 images
# Epoch [4], Processed 2000/3986 images
# Epoch [4], Processed 2100/3986 images
# Epoch [4], Processed 2200/3986 images
# Epoch [4], Processed 2300/3986 images
# Epoch [4], Processed 2400/3986 images
# Epoch [4], Processed 2500/3986 images
# Epoch [4], Processed 2600/3986 images
# Epoch [4], Processed 2700/3986 images
# Epoch [4], Processed 2800/3986 images
# Epoch [4], Processed 2900/3986 images
# Epoch [4], Processed 3000/3986 images
# Epoch [4], Processed 3100/3986 images
# Epoch [4], Processed 3200/3986 images
# Epoch [4], Processed 3300/3986 images
# Epoch [4], Processed 3400/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [4], Processed 3500/3986 images
# Epoch [4], Processed 3600/3986 images
# Epoch [4], Processed 3700/3986 images
# Epoch [4], Processed 3800/3986 images
# Epoch [4], Processed 3900/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [4], Training Loss: 4.81695556341705
# Epoch [4], Validation Loss: 4.903432780742645
# Epoch [4], Validation Class Loss: 0.532730817437172
# Epoch [4], Validation Box Loss: 0.30306037228269267
# Epoch [4], Validation Mask Loss: 0.611172809123993
# mAP@50: 0.035438279933530395, Precision: 0.035438279933530395, Recall: 0.053599687952747124
# Saved checkpoint for Epoch 4 at /kaggle/working/model_epoch_4.pth
# Best model saved at Epoch 4 with Validation Loss: 4.903432780742645
# Epoch [5], Processed 100/3986 images
# Epoch [5], Processed 200/3986 images
# Epoch [5], Processed 300/3986 images
# Epoch [5], Processed 400/3986 images
# Epoch [5], Processed 500/3986 images
# Epoch [5], Processed 600/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [5], Processed 700/3986 images
# Epoch [5], Processed 800/3986 images
# Epoch [5], Processed 900/3986 images
# Epoch [5], Processed 1000/3986 images
# Epoch [5], Processed 1100/3986 images
# Epoch [5], Processed 1200/3986 images
# Epoch [5], Processed 1300/3986 images
# Epoch [5], Processed 1400/3986 images
# Epoch [5], Processed 1500/3986 images
# Epoch [5], Processed 1600/3986 images
# Epoch [5], Processed 1700/3986 images
# Epoch [5], Processed 1800/3986 images
# Epoch [5], Processed 1900/3986 images
# Epoch [5], Processed 2000/3986 images
# Epoch [5], Processed 2100/3986 images
# Epoch [5], Processed 2200/3986 images
# Epoch [5], Processed 2300/3986 images
# Epoch [5], Processed 2400/3986 images
# Epoch [5], Processed 2500/3986 images
# Epoch [5], Processed 2600/3986 images
# Epoch [5], Processed 2700/3986 images
# Epoch [5], Processed 2800/3986 images
# Epoch [5], Processed 2900/3986 images
# Epoch [5], Processed 3000/3986 images
# Epoch [5], Processed 3100/3986 images
# Epoch [5], Processed 3200/3986 images
# Epoch [5], Processed 3300/3986 images
# Epoch [5], Processed 3400/3986 images
# Epoch [5], Processed 3500/3986 images
# Epoch [5], Processed 3600/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [5], Processed 3700/3986 images
# Epoch [5], Processed 3800/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [5], Processed 3900/3986 images
# Epoch [5], Training Loss: 4.764846238472995
# Epoch [5], Validation Loss: 4.947039494514465
# Epoch [5], Validation Class Loss: 0.5048570787012577
# Epoch [5], Validation Box Loss: 0.28599833324526114
# Epoch [5], Validation Mask Loss: 0.6081241352558135
# mAP@50: 0.033554730959445105, Precision: 0.033554730959445105, Recall: 0.051650984700132144
# Saved checkpoint for Epoch 5 at /kaggle/working/model_epoch_5.pth
# Epoch [6], Processed 100/3986 images
# Epoch [6], Processed 200/3986 images
# Epoch [6], Processed 300/3986 images
# Epoch [6], Processed 400/3986 images
# Epoch [6], Processed 500/3986 images
# Epoch [6], Processed 600/3986 images
# Epoch [6], Processed 700/3986 images
# Epoch [6], Processed 800/3986 images
# Epoch [6], Processed 900/3986 images
# Epoch [6], Processed 1000/3986 images
# Epoch [6], Processed 1100/3986 images
# Epoch [6], Processed 1200/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [6], Processed 1300/3986 images
# Epoch [6], Processed 1400/3986 images
# Epoch [6], Processed 1500/3986 images
# Epoch [6], Processed 1600/3986 images
# Epoch [6], Processed 1700/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [6], Processed 1800/3986 images
# Epoch [6], Processed 1900/3986 images
# Epoch [6], Processed 2000/3986 images
# Epoch [6], Processed 2100/3986 images
# Epoch [6], Processed 2200/3986 images
# Epoch [6], Processed 2300/3986 images
# Epoch [6], Processed 2400/3986 images
# Epoch [6], Processed 2500/3986 images
# Epoch [6], Processed 2600/3986 images
# Epoch [6], Processed 2700/3986 images
# Epoch [6], Processed 2800/3986 images
# Epoch [6], Processed 2900/3986 images
# Epoch [6], Processed 3000/3986 images
# Epoch [6], Processed 3100/3986 images
# Epoch [6], Processed 3200/3986 images
# Epoch [6], Processed 3300/3986 images
# Epoch [6], Processed 3400/3986 images
# Epoch [6], Processed 3500/3986 images
# Epoch [6], Processed 3600/3986 images
# Epoch [6], Processed 3700/3986 images
# Epoch [6], Processed 3800/3986 images
# Epoch [6], Processed 3900/3986 images
# Epoch [6], Training Loss: 4.750018829806757
# Epoch [6], Validation Loss: 4.772487580299377
# Epoch [6], Validation Class Loss: 0.5193897821307182
# Epoch [6], Validation Box Loss: 0.2919243046331685
# Epoch [6], Validation Mask Loss: 0.6087218277454376
# mAP@50: 0.0436527837480696, Precision: 0.0436527837480696, Recall: 0.05336804062982598
# Saved checkpoint for Epoch 6 at /kaggle/working/model_epoch_6.pth
# Best model saved at Epoch 6 with Validation Loss: 4.772487580299377
# Epoch [7], Processed 100/3986 images
# Epoch [7], Processed 200/3986 images
# Epoch [7], Processed 300/3986 images
# Epoch [7], Processed 400/3986 images
# Epoch [7], Processed 500/3986 images
# Epoch [7], Processed 600/3986 images
# Epoch [7], Processed 700/3986 images
# Epoch [7], Processed 800/3986 images
# Epoch [7], Processed 900/3986 images
# Epoch [7], Processed 1000/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [7], Processed 1100/3986 images
# Epoch [7], Processed 1200/3986 images
# Epoch [7], Processed 1300/3986 images
# Epoch [7], Processed 1400/3986 images
# Epoch [7], Processed 1500/3986 images
# Epoch [7], Processed 1600/3986 images
# Epoch [7], Processed 1700/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [7], Processed 1800/3986 images
# Epoch [7], Processed 1900/3986 images
# Epoch [7], Processed 2000/3986 images
# Epoch [7], Processed 2100/3986 images
# Epoch [7], Processed 2200/3986 images
# Epoch [7], Processed 2300/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [7], Processed 2400/3986 images
# Epoch [7], Processed 2500/3986 images
# Epoch [7], Processed 2600/3986 images
# Epoch [7], Processed 2700/3986 images
# Epoch [7], Processed 2800/3986 images
# Epoch [7], Processed 2900/3986 images
# Epoch [7], Processed 3000/3986 images
# Epoch [7], Processed 3100/3986 images
# Epoch [7], Processed 3200/3986 images
# Epoch [7], Processed 3300/3986 images
# Epoch [7], Processed 3400/3986 images
# Epoch [7], Processed 3500/3986 images
# Epoch [7], Processed 3600/3986 images
# Epoch [7], Processed 3700/3986 images
# Epoch [7], Processed 3800/3986 images
# Epoch [7], Processed 3900/3986 images
# Epoch [7], Training Loss: 4.664666931870708
# Epoch [7], Validation Loss: 4.587716331958771
# Epoch [7], Validation Class Loss: 0.4990774529576302
# Epoch [7], Validation Box Loss: 0.27812550440135236
# Epoch [7], Validation Mask Loss: 0.6069232966899872
# mAP@50: 0.028389316562962213, Precision: 0.028389316562962213, Recall: 0.06611938991577908
# Saved checkpoint for Epoch 7 at /kaggle/working/model_epoch_7.pth
# Best model saved at Epoch 7 with Validation Loss: 4.587716331958771
# Epoch [8], Processed 100/3986 images
# Epoch [8], Processed 200/3986 images
# Epoch [8], Processed 300/3986 images
# Epoch [8], Processed 400/3986 images
# Epoch [8], Processed 500/3986 images
# Epoch [8], Processed 600/3986 images
# Epoch [8], Processed 700/3986 images
# Epoch [8], Processed 800/3986 images
# Epoch [8], Processed 900/3986 images
# Epoch [8], Processed 1000/3986 images
# Epoch [8], Processed 1100/3986 images
# Epoch [8], Processed 1200/3986 images
# Epoch [8], Processed 1300/3986 images
# Epoch [8], Processed 1400/3986 images
# Epoch [8], Processed 1500/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [8], Processed 1600/3986 images
# Epoch [8], Processed 1700/3986 images
# Epoch [8], Processed 1800/3986 images
# Epoch [8], Processed 1900/3986 images
# Epoch [8], Processed 2000/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [8], Processed 2100/3986 images
# Epoch [8], Processed 2200/3986 images
# Epoch [8], Processed 2300/3986 images
# Epoch [8], Processed 2400/3986 images
# Epoch [8], Processed 2500/3986 images
# Epoch [8], Processed 2600/3986 images
# Epoch [8], Processed 2700/3986 images
# Epoch [8], Processed 2800/3986 images
# Epoch [8], Processed 2900/3986 images
# Epoch [8], Processed 3000/3986 images
# Epoch [8], Processed 3100/3986 images
# Epoch [8], Processed 3200/3986 images
# Epoch [8], Processed 3300/3986 images
# Epoch [8], Processed 3400/3986 images
# Epoch [8], Processed 3500/3986 images
# Epoch [8], Processed 3600/3986 images
# Epoch [8], Processed 3700/3986 images
# Epoch [8], Processed 3800/3986 images
# Epoch [8], Processed 3900/3986 images
# Epoch [8], Training Loss: 4.6454906851023345
# Epoch [8], Validation Loss: 4.580293950080872
# Epoch [8], Validation Class Loss: 0.5023870718777179
# Epoch [8], Validation Box Loss: 0.28523364966287046
# Epoch [8], Validation Mask Loss: 0.6078704543113709
# mAP@50: 0.042274907194666464, Precision: 0.042274907194666464, Recall: 0.050044976198436585
# Saved checkpoint for Epoch 8 at /kaggle/working/model_epoch_8.pth
# Best model saved at Epoch 8 with Validation Loss: 4.580293950080872
# Epoch [9], Processed 100/3986 images
# Epoch [9], Processed 200/3986 images
# Epoch [9], Processed 300/3986 images
# Epoch [9], Processed 400/3986 images
# Epoch [9], Processed 500/3986 images
# Epoch [9], Processed 600/3986 images
# Epoch [9], Processed 700/3986 images
# Epoch [9], Processed 800/3986 images
# Epoch [9], Processed 900/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [9], Processed 1000/3986 images
# Epoch [9], Processed 1100/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [9], Processed 1200/3986 images
# Epoch [9], Processed 1300/3986 images
# Epoch [9], Processed 1400/3986 images
# Epoch [9], Processed 1500/3986 images
# Epoch [9], Processed 1600/3986 images
# Epoch [9], Processed 1700/3986 images
# Epoch [9], Processed 1800/3986 images
# Epoch [9], Processed 1900/3986 images
# Epoch [9], Processed 2000/3986 images
# Epoch [9], Processed 2100/3986 images
# Epoch [9], Processed 2200/3986 images
# Epoch [9], Processed 2300/3986 images
# Epoch [9], Processed 2400/3986 images
# Epoch [9], Processed 2500/3986 images
# Epoch [9], Processed 2600/3986 images
# Epoch [9], Processed 2700/3986 images
# Epoch [9], Processed 2800/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [9], Processed 2900/3986 images
# Epoch [9], Processed 3000/3986 images
# Epoch [9], Processed 3100/3986 images
# Epoch [9], Processed 3200/3986 images
# Epoch [9], Processed 3300/3986 images
# Epoch [9], Processed 3400/3986 images
# Epoch [9], Processed 3500/3986 images
# Epoch [9], Processed 3600/3986 images
# Epoch [9], Processed 3700/3986 images
# Epoch [9], Processed 3800/3986 images
# Epoch [9], Processed 3900/3986 images
# Epoch [9], Training Loss: 4.628637185426748
# Epoch [9], Validation Loss: 4.900265745639801
# Epoch [9], Validation Class Loss: 0.5025241082310676
# Epoch [9], Validation Box Loss: 0.2812516444795765
# Epoch [9], Validation Mask Loss: 0.6039281878471374
# mAP@50: 0.02631207853257101, Precision: 0.02631207853257101, Recall: 0.08108651350878032
# Saved checkpoint for Epoch 9 at /kaggle/working/model_epoch_9.pth
# Epoch [10], Processed 100/3986 images
# Epoch [10], Processed 200/3986 images
# Epoch [10], Processed 300/3986 images
# Epoch [10], Processed 400/3986 images
# Epoch [10], Processed 500/3986 images
# Epoch [10], Processed 600/3986 images
# Epoch [10], Processed 700/3986 images
# Epoch [10], Processed 800/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [10], Processed 900/3986 images
# Epoch [10], Processed 1000/3986 images
# Epoch [10], Processed 1100/3986 images
# Epoch [10], Processed 1200/3986 images
# Epoch [10], Processed 1300/3986 images
# Epoch [10], Processed 1400/3986 images
# Epoch [10], Processed 1500/3986 images
# Epoch [10], Processed 1600/3986 images
# Epoch [10], Processed 1700/3986 images
# Epoch [10], Processed 1800/3986 images
# Epoch [10], Processed 1900/3986 images
# Epoch [10], Processed 2000/3986 images
# Epoch [10], Processed 2100/3986 images
# Epoch [10], Processed 2200/3986 images
# Epoch [10], Processed 2300/3986 images
# Epoch [10], Processed 2400/3986 images
# Epoch [10], Processed 2500/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [10], Processed 2600/3986 images
# Epoch [10], Processed 2700/3986 images
# Epoch [10], Processed 2800/3986 images
# Epoch [10], Processed 2900/3986 images
# Epoch [10], Processed 3000/3986 images
# Epoch [10], Processed 3100/3986 images
# Epoch [10], Processed 3200/3986 images
# Epoch [10], Processed 3300/3986 images
# Epoch [10], Processed 3400/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [10], Processed 3500/3986 images
# Epoch [10], Processed 3600/3986 images
# Epoch [10], Processed 3700/3986 images
# Epoch [10], Processed 3800/3986 images
# Epoch [10], Processed 3900/3986 images
# Epoch [10], Training Loss: 4.563009710943208
# Epoch [10], Validation Loss: 4.509956798553467
# Epoch [10], Validation Class Loss: 0.48275992447137833
# Epoch [10], Validation Box Loss: 0.2719867860832601
# Epoch [10], Validation Mask Loss: 0.6033707149028779
# mAP@50: 0.039301926988516166, Precision: 0.039301926988516166, Recall: 0.075043782140071
# Saved checkpoint for Epoch 10 at /kaggle/working/model_epoch_10.pth
# Best model saved at Epoch 10 with Validation Loss: 4.509956798553467
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [11], Processed 100/3986 images
# Epoch [11], Processed 200/3986 images
# Epoch [11], Processed 300/3986 images
# Epoch [11], Processed 400/3986 images
# Epoch [11], Processed 500/3986 images
# Epoch [11], Processed 600/3986 images
# Epoch [11], Processed 700/3986 images
# Epoch [11], Processed 800/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [11], Processed 900/3986 images
# Epoch [11], Processed 1000/3986 images
# Epoch [11], Processed 1100/3986 images
# Epoch [11], Processed 1200/3986 images
# Epoch [11], Processed 1300/3986 images
# Epoch [11], Processed 1400/3986 images
# Epoch [11], Processed 1500/3986 images
# Epoch [11], Processed 1600/3986 images
# Epoch [11], Processed 1700/3986 images
# Epoch [11], Processed 1800/3986 images
# Epoch [11], Processed 1900/3986 images
# Epoch [11], Processed 2000/3986 images
# Epoch [11], Processed 2100/3986 images
# Epoch [11], Processed 2200/3986 images
# Epoch [11], Processed 2300/3986 images
# Epoch [11], Processed 2400/3986 images
# Epoch [11], Processed 2500/3986 images
# Epoch [11], Processed 2600/3986 images
# Epoch [11], Processed 2700/3986 images
# Epoch [11], Processed 2800/3986 images
# Epoch [11], Processed 2900/3986 images
# Epoch [11], Processed 3000/3986 images
# Epoch [11], Processed 3100/3986 images
# Epoch [11], Processed 3200/3986 images
# Epoch [11], Processed 3300/3986 images
# Epoch [11], Processed 3400/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [11], Processed 3500/3986 images
# Epoch [11], Processed 3600/3986 images
# Epoch [11], Processed 3700/3986 images
# Epoch [11], Processed 3800/3986 images
# Epoch [11], Processed 3900/3986 images
# Epoch [11], Training Loss: 4.500640514741092
# Epoch [11], Validation Loss: 4.94600040102005
# Epoch [11], Validation Class Loss: 0.490178875118494
# Epoch [11], Validation Box Loss: 0.2793371867674578
# Epoch [11], Validation Mask Loss: 0.6025533716678619
# mAP@50: 0.03793774403556536, Precision: 0.03793774403556536, Recall: 0.06366520195507155
# Saved checkpoint for Epoch 11 at /kaggle/working/model_epoch_11.pth
# Epoch [12], Processed 100/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [12], Processed 200/3986 images
# Epoch [12], Processed 300/3986 images
# Epoch [12], Processed 400/3986 images
# Epoch [12], Processed 500/3986 images
# Epoch [12], Processed 600/3986 images
# Epoch [12], Processed 700/3986 images
# Epoch [12], Processed 800/3986 images
# Epoch [12], Processed 900/3986 images
# Epoch [12], Processed 1000/3986 images
# Epoch [12], Processed 1100/3986 images
# Epoch [12], Processed 1200/3986 images
# Epoch [12], Processed 1300/3986 images
# Epoch [12], Processed 1400/3986 images
# Epoch [12], Processed 1500/3986 images
# Epoch [12], Processed 1600/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [12], Processed 1700/3986 images
# Epoch [12], Processed 1800/3986 images
# Epoch [12], Processed 1900/3986 images
# Epoch [12], Processed 2000/3986 images
# Epoch [12], Processed 2100/3986 images
# Epoch [12], Processed 2200/3986 images
# Epoch [12], Processed 2300/3986 images
# Epoch [12], Processed 2400/3986 images
# Epoch [12], Processed 2500/3986 images
# Epoch [12], Processed 2600/3986 images
# Epoch [12], Processed 2700/3986 images
# Epoch [12], Processed 2800/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [12], Processed 2900/3986 images
# Epoch [12], Processed 3000/3986 images
# Epoch [12], Processed 3100/3986 images
# Epoch [12], Processed 3200/3986 images
# Epoch [12], Processed 3300/3986 images
# Epoch [12], Processed 3400/3986 images
# Epoch [12], Processed 3500/3986 images
# Epoch [12], Processed 3600/3986 images
# Epoch [12], Processed 3700/3986 images
# Epoch [12], Processed 3800/3986 images
# Epoch [12], Processed 3900/3986 images
# Epoch [12], Training Loss: 4.506689793008978
# Epoch [12], Validation Loss: 4.64312167930603
# Epoch [12], Validation Class Loss: 0.5002542707920075
# Epoch [12], Validation Box Loss: 0.2871102819577791
# Epoch [12], Validation Mask Loss: 0.5990800187587738
# mAP@50: 0.03313829765901724, Precision: 0.03313829765901724, Recall: 0.09345138590374297
# Saved checkpoint for Epoch 12 at /kaggle/working/model_epoch_12.pth
# Epoch [13], Processed 100/3986 images
# Epoch [13], Processed 200/3986 images
# Epoch [13], Processed 300/3986 images
# Epoch [13], Processed 400/3986 images
# Epoch [13], Processed 500/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [13], Processed 600/3986 images
# Epoch [13], Processed 700/3986 images
# Epoch [13], Processed 800/3986 images
# Epoch [13], Processed 900/3986 images
# Epoch [13], Processed 1000/3986 images
# Epoch [13], Processed 1100/3986 images
# Epoch [13], Processed 1200/3986 images
# Epoch [13], Processed 1300/3986 images
# Epoch [13], Processed 1400/3986 images
# Epoch [13], Processed 1500/3986 images
# Epoch [13], Processed 1600/3986 images
# Epoch [13], Processed 1700/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [13], Processed 1800/3986 images
# Epoch [13], Processed 1900/3986 images
# Epoch [13], Processed 2000/3986 images
# Epoch [13], Processed 2100/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [13], Processed 2200/3986 images
# Epoch [13], Processed 2300/3986 images
# Epoch [13], Processed 2400/3986 images
# Epoch [13], Processed 2500/3986 images
# Epoch [13], Processed 2600/3986 images
# Epoch [13], Processed 2700/3986 images
# Epoch [13], Processed 2800/3986 images
# Epoch [13], Processed 2900/3986 images
# Epoch [13], Processed 3000/3986 images
# Epoch [13], Processed 3100/3986 images
# Epoch [13], Processed 3200/3986 images
# Epoch [13], Processed 3300/3986 images
# Epoch [13], Processed 3400/3986 images
# Epoch [13], Processed 3500/3986 images
# Epoch [13], Processed 3600/3986 images
# Epoch [13], Processed 3700/3986 images
# Epoch [13], Processed 3800/3986 images
# Epoch [13], Processed 3900/3986 images
# Epoch [13], Training Loss: 4.49026010292344
# Epoch [13], Validation Loss: 4.6911709651947024
# Epoch [13], Validation Class Loss: 0.5086759667396545
# Epoch [13], Validation Box Loss: 0.28797591912893405
# Epoch [13], Validation Mask Loss: 0.5967296130657196
# mAP@50: 0.03845482068118074, Precision: 0.03845482068118074, Recall: 0.06915826845616214
# Saved checkpoint for Epoch 13 at /kaggle/working/model_epoch_13.pth
# Epoch [14], Processed 100/3986 images
# Epoch [14], Processed 200/3986 images
# Epoch [14], Processed 300/3986 images
# Epoch [14], Processed 400/3986 images
# Epoch [14], Processed 500/3986 images
# Epoch [14], Processed 600/3986 images
# Epoch [14], Processed 700/3986 images
# Epoch [14], Processed 800/3986 images
# Epoch [14], Processed 900/3986 images
# Epoch [14], Processed 1000/3986 images
# Epoch [14], Processed 1100/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [14], Processed 1200/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [14], Processed 1300/3986 images
# Epoch [14], Processed 1400/3986 images
# Epoch [14], Processed 1500/3986 images
# Epoch [14], Processed 1600/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [14], Processed 1700/3986 images
# Epoch [14], Processed 1800/3986 images
# Epoch [14], Processed 1900/3986 images
# Epoch [14], Processed 2000/3986 images
# Epoch [14], Processed 2100/3986 images
# Epoch [14], Processed 2200/3986 images
# Epoch [14], Processed 2300/3986 images
# Epoch [14], Processed 2400/3986 images
# Epoch [14], Processed 2500/3986 images
# Epoch [14], Processed 2600/3986 images
# Epoch [14], Processed 2700/3986 images
# Epoch [14], Processed 2800/3986 images
# Epoch [14], Processed 2900/3986 images
# Epoch [14], Processed 3000/3986 images
# Epoch [14], Processed 3100/3986 images
# Epoch [14], Processed 3200/3986 images
# Epoch [14], Processed 3300/3986 images
# Epoch [14], Processed 3400/3986 images
# Epoch [14], Processed 3500/3986 images
# Epoch [14], Processed 3600/3986 images
# Epoch [14], Processed 3700/3986 images
# Epoch [14], Processed 3800/3986 images
# Epoch [14], Processed 3900/3986 images
# Epoch [14], Training Loss: 4.467378488275687
# Epoch [14], Validation Loss: 4.488372577667237
# Epoch [14], Validation Class Loss: 0.49911227089166643
# Epoch [14], Validation Box Loss: 0.2821000300145242
# Epoch [14], Validation Mask Loss: 0.597402988910675
# mAP@50: 0.028659651485714116, Precision: 0.028659651485714116, Recall: 0.10625646781614685
# Saved checkpoint for Epoch 14 at /kaggle/working/model_epoch_14.pth
# Best model saved at Epoch 14 with Validation Loss: 4.488372577667237
# Epoch [15], Processed 100/3986 images
# Epoch [15], Processed 200/3986 images
# Epoch [15], Processed 300/3986 images
# Epoch [15], Processed 400/3986 images
# Epoch [15], Processed 500/3986 images
# Epoch [15], Processed 600/3986 images
# Epoch [15], Processed 700/3986 images
# Epoch [15], Processed 800/3986 images
# Epoch [15], Processed 900/3986 images
# Epoch [15], Processed 1000/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [15], Processed 1100/3986 images
# Epoch [15], Processed 1200/3986 images
# Epoch [15], Processed 1300/3986 images
# Epoch [15], Processed 1400/3986 images
# Epoch [15], Processed 1500/3986 images
# Epoch [15], Processed 1600/3986 images
# Epoch [15], Processed 1700/3986 images
# Epoch [15], Processed 1800/3986 images
# Epoch [15], Processed 1900/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [15], Processed 2000/3986 images
# Epoch [15], Processed 2100/3986 images
# Epoch [15], Processed 2200/3986 images
# Epoch [15], Processed 2300/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [15], Processed 2400/3986 images
# Epoch [15], Processed 2500/3986 images
# Epoch [15], Processed 2600/3986 images
# Epoch [15], Processed 2700/3986 images
# Epoch [15], Processed 2800/3986 images
# Epoch [15], Processed 2900/3986 images
# Epoch [15], Processed 3000/3986 images
# Epoch [15], Processed 3100/3986 images
# Epoch [15], Processed 3200/3986 images
# Epoch [15], Processed 3300/3986 images
# Epoch [15], Processed 3400/3986 images
# Epoch [15], Processed 3500/3986 images
# Epoch [15], Processed 3600/3986 images
# Epoch [15], Processed 3700/3986 images
# Epoch [15], Processed 3800/3986 images
# Epoch [15], Processed 3900/3986 images
# Epoch [15], Training Loss: 4.4858555163638885
# Epoch [15], Validation Loss: 4.753806574821472
# Epoch [15], Validation Class Loss: 0.494080011844635
# Epoch [15], Validation Box Loss: 0.2781793880185287
# Epoch [15], Validation Mask Loss: 0.5940934431552887
# mAP@50: 0.03007107113952036, Precision: 0.03007107113952036, Recall: 0.1135087803091815
# Saved checkpoint for Epoch 15 at /kaggle/working/model_epoch_15.pth
# Epoch [16], Processed 100/3986 images
# Epoch [16], Processed 200/3986 images
# Epoch [16], Processed 300/3986 images
# Epoch [16], Processed 400/3986 images
# Epoch [16], Processed 500/3986 images
# Epoch [16], Processed 600/3986 images
# Epoch [16], Processed 700/3986 images
# Epoch [16], Processed 800/3986 images
# Epoch [16], Processed 900/3986 images
# Epoch [16], Processed 1000/3986 images
# Epoch [16], Processed 1100/3986 images
# Epoch [16], Processed 1200/3986 images
# Epoch [16], Processed 1300/3986 images
# Epoch [16], Processed 1400/3986 images
# Epoch [16], Processed 1500/3986 images
# Epoch [16], Processed 1600/3986 images
# Epoch [16], Processed 1700/3986 images
# Epoch [16], Processed 1800/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [16], Processed 1900/3986 images
# Epoch [16], Processed 2000/3986 images
# Epoch [16], Processed 2100/3986 images
# Epoch [16], Processed 2200/3986 images
# Epoch [16], Processed 2300/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [16], Processed 2400/3986 images
# Epoch [16], Processed 2500/3986 images
# Epoch [16], Processed 2600/3986 images
# Epoch [16], Processed 2700/3986 images
# Epoch [16], Processed 2800/3986 images
# Epoch [16], Processed 2900/3986 images
# Epoch [16], Processed 3000/3986 images
# Epoch [16], Processed 3100/3986 images
# Epoch [16], Processed 3200/3986 images
# Epoch [16], Processed 3300/3986 images
# Epoch [16], Processed 3400/3986 images
# Epoch [16], Processed 3500/3986 images
# Epoch [16], Processed 3600/3986 images
# Epoch [16], Processed 3700/3986 images
# Epoch [16], Processed 3800/3986 images
# Epoch [16], Processed 3900/3986 images
# Epoch [16], Training Loss: 4.409571113175112
# Epoch [16], Validation Loss: 4.668975876331329
# Epoch [16], Validation Class Loss: 0.5020037041902542
# Epoch [16], Validation Box Loss: 0.28787578897683125
# Epoch [16], Validation Mask Loss: 0.5977859289646149
# mAP@50: 0.03581800365026925, Precision: 0.03581800365026925, Recall: 0.07858456321344987
# Saved checkpoint for Epoch 16 at /kaggle/working/model_epoch_16.pth
# Epoch [17], Processed 100/3986 images
# Epoch [17], Processed 200/3986 images
# Epoch [17], Processed 300/3986 images
# Epoch [17], Processed 400/3986 images
# Epoch [17], Processed 500/3986 images
# Epoch [17], Processed 600/3986 images
# Epoch [17], Processed 700/3986 images
# Epoch [17], Processed 800/3986 images
# Epoch [17], Processed 900/3986 images
# Epoch [17], Processed 1000/3986 images
# Epoch [17], Processed 1100/3986 images
# Epoch [17], Processed 1200/3986 images
# Epoch [17], Processed 1300/3986 images
# Epoch [17], Processed 1400/3986 images
# Epoch [17], Processed 1500/3986 images
# Epoch [17], Processed 1600/3986 images
# Epoch [17], Processed 1700/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [17], Processed 1800/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [17], Processed 1900/3986 images
# Epoch [17], Processed 2000/3986 images
# Epoch [17], Processed 2100/3986 images
# Epoch [17], Processed 2200/3986 images
# Epoch [17], Processed 2300/3986 images
# Epoch [17], Processed 2400/3986 images
# Epoch [17], Processed 2500/3986 images
# Epoch [17], Processed 2600/3986 images
# Epoch [17], Processed 2700/3986 images
# Epoch [17], Processed 2800/3986 images
# Epoch [17], Processed 2900/3986 images
# Epoch [17], Processed 3000/3986 images
# Epoch [17], Processed 3100/3986 images
# Epoch [17], Processed 3200/3986 images
# Epoch [17], Processed 3300/3986 images
# Epoch [17], Processed 3400/3986 images
# Epoch [17], Processed 3500/3986 images
# Epoch [17], Processed 3600/3986 images
# Epoch [17], Processed 3700/3986 images
# Epoch [17], Processed 3800/3986 images
# Epoch [17], Processed 3900/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [17], Training Loss: 4.424332285357813
# Epoch [17], Validation Loss: 4.546539063930512
# Epoch [17], Validation Class Loss: 0.48752246344089506
# Epoch [17], Validation Box Loss: 0.2742685553692281
# Epoch [17], Validation Mask Loss: 0.5975985293388366
# mAP@50: 0.031527187723584225, Precision: 0.031527187723584225, Recall: 0.10772714970307748
# Saved checkpoint for Epoch 17 at /kaggle/working/model_epoch_17.pth
# Epoch [18], Processed 100/3986 images
# Epoch [18], Processed 200/3986 images
# Epoch [18], Processed 300/3986 images
# Epoch [18], Processed 400/3986 images
# Epoch [18], Processed 500/3986 images
# Epoch [18], Processed 600/3986 images
# Epoch [18], Processed 700/3986 images
# Epoch [18], Processed 800/3986 images
# Epoch [18], Processed 900/3986 images
# Epoch [18], Processed 1000/3986 images
# Epoch [18], Processed 1100/3986 images
# Epoch [18], Processed 1200/3986 images
# Epoch [18], Processed 1300/3986 images
# Epoch [18], Processed 1400/3986 images
# Epoch [18], Processed 1500/3986 images
# Epoch [18], Processed 1600/3986 images
# Epoch [18], Processed 1700/3986 images
# Epoch [18], Processed 1800/3986 images
# Epoch [18], Processed 1900/3986 images
# Epoch [18], Processed 2000/3986 images
# Epoch [18], Processed 2100/3986 images
# Epoch [18], Processed 2200/3986 images
# Epoch [18], Processed 2300/3986 images
# Epoch [18], Processed 2400/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [18], Processed 2500/3986 images
# Epoch [18], Processed 2600/3986 images
# Epoch [18], Processed 2700/3986 images
# Epoch [18], Processed 2800/3986 images
# Epoch [18], Processed 2900/3986 images
# Epoch [18], Processed 3000/3986 images
# Epoch [18], Processed 3100/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [18], Processed 3200/3986 images
# Epoch [18], Processed 3300/3986 images
# Epoch [18], Processed 3400/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [18], Processed 3500/3986 images
# Epoch [18], Processed 3600/3986 images
# Epoch [18], Processed 3700/3986 images
# Epoch [18], Processed 3800/3986 images
# Epoch [18], Processed 3900/3986 images
# Epoch [18], Training Loss: 4.359787284072447
# Epoch [18], Validation Loss: 4.445013014793396
# Epoch [18], Validation Class Loss: 0.5075712431669235
# Epoch [18], Validation Box Loss: 0.2880791351218068
# Epoch [18], Validation Mask Loss: 0.5923346519470215
# mAP@50: 0.03414613190722092, Precision: 0.03414613190722092, Recall: 0.09076196844501759
# Saved checkpoint for Epoch 18 at /kaggle/working/model_epoch_18.pth
# Best model saved at Epoch 18 with Validation Loss: 4.445013014793396
# Epoch [19], Processed 100/3986 images
# Epoch [19], Processed 200/3986 images
# Epoch [19], Processed 300/3986 images
# Epoch [19], Processed 400/3986 images
# Epoch [19], Processed 500/3986 images
# Epoch [19], Processed 600/3986 images
# Epoch [19], Processed 700/3986 images
# Epoch [19], Processed 800/3986 images
# Epoch [19], Processed 900/3986 images
# Epoch [19], Processed 1000/3986 images
# Epoch [19], Processed 1100/3986 images
# Epoch [19], Processed 1200/3986 images
# Epoch [19], Processed 1300/3986 images
# Epoch [19], Processed 1400/3986 images
# Epoch [19], Processed 1500/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [19], Processed 1600/3986 images
# Epoch [19], Processed 1700/3986 images
# Epoch [19], Processed 1800/3986 images
# Epoch [19], Processed 1900/3986 images
# Epoch [19], Processed 2000/3986 images
# Epoch [19], Processed 2100/3986 images
# Epoch [19], Processed 2200/3986 images
# Epoch [19], Processed 2300/3986 images
# Epoch [19], Processed 2400/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [19], Processed 2500/3986 images
# Epoch [19], Processed 2600/3986 images
# Epoch [19], Processed 2700/3986 images
# Epoch [19], Processed 2800/3986 images
# Epoch [19], Processed 2900/3986 images
# Epoch [19], Processed 3000/3986 images
# Epoch [19], Processed 3100/3986 images
# Epoch [19], Processed 3200/3986 images
# Epoch [19], Processed 3300/3986 images
# Epoch [19], Processed 3400/3986 images
# Epoch [19], Processed 3500/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [19], Processed 3600/3986 images
# Epoch [19], Processed 3700/3986 images
# Epoch [19], Processed 3800/3986 images
# Epoch [19], Processed 3900/3986 images
# Epoch [19], Training Loss: 4.372534550061316
# Epoch [19], Validation Loss: 4.633202726364136
# Epoch [19], Validation Class Loss: 0.48082792779803274
# Epoch [19], Validation Box Loss: 0.27792126657580957
# Epoch [19], Validation Mask Loss: 0.5928486249446869
# mAP@50: 0.02994113187153648, Precision: 0.02994113187153648, Recall: 0.0979231344828135
# Saved checkpoint for Epoch 19 at /kaggle/working/model_epoch_19.pth
# Epoch [20], Processed 100/3986 images
# Epoch [20], Processed 200/3986 images
# Epoch [20], Processed 300/3986 images
# Epoch [20], Processed 400/3986 images
# Epoch [20], Processed 500/3986 images
# Epoch [20], Processed 600/3986 images
# Epoch [20], Processed 700/3986 images
# Epoch [20], Processed 800/3986 images
# Epoch [20], Processed 900/3986 images
# Epoch [20], Processed 1000/3986 images
# Epoch [20], Processed 1100/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [20], Processed 1200/3986 images
# Epoch [20], Processed 1300/3986 images
# Epoch [20], Processed 1400/3986 images
# Epoch [20], Processed 1500/3986 images
# Epoch [20], Processed 1600/3986 images
# Epoch [20], Processed 1700/3986 images
# Epoch [20], Processed 1800/3986 images
# Epoch [20], Processed 1900/3986 images
# Epoch [20], Processed 2000/3986 images
# Epoch [20], Processed 2100/3986 images
# Epoch [20], Processed 2200/3986 images
# Epoch [20], Processed 2300/3986 images
# Epoch [20], Processed 2400/3986 images
# Epoch [20], Processed 2500/3986 images
# Epoch [20], Processed 2600/3986 images
# Epoch [20], Processed 2700/3986 images
# Epoch [20], Processed 2800/3986 images
# Epoch [20], Processed 2900/3986 images
# Epoch [20], Processed 3000/3986 images
# Epoch [20], Processed 3100/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [20], Processed 3200/3986 images
# Epoch [20], Processed 3300/3986 images
# Epoch [20], Processed 3400/3986 images
# Epoch [20], Processed 3500/3986 images
# Epoch [20], Processed 3600/3986 images
# Epoch [20], Processed 3700/3986 images
# Epoch [20], Processed 3800/3986 images
# Epoch [20], Processed 3900/3986 images
# Epoch [20], Training Loss: 4.380830501900274
# Epoch [20], Validation Loss: 4.707681187152863
# Epoch [20], Validation Class Loss: 0.47705302941799166
# Epoch [20], Validation Box Loss: 0.2770838877739734
# Epoch [20], Validation Mask Loss: 0.594072943687439
# mAP@50: 0.03888650968270998, Precision: 0.03888650968270998, Recall: 0.09388522710990113
# Saved checkpoint for Epoch 20 at /kaggle/working/model_epoch_20.pth
# Epoch [21], Processed 100/3986 images
# Epoch [21], Processed 200/3986 images
# Epoch [21], Processed 300/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [21], Processed 400/3986 images
# Epoch [21], Processed 500/3986 images
# Epoch [21], Processed 600/3986 images
# Epoch [21], Processed 700/3986 images
# Epoch [21], Processed 800/3986 images
# Epoch [21], Processed 900/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [21], Processed 1000/3986 images
# Epoch [21], Processed 1100/3986 images
# Epoch [21], Processed 1200/3986 images
# Epoch [21], Processed 1300/3986 images
# Epoch [21], Processed 1400/3986 images
# Epoch [21], Processed 1500/3986 images
# Epoch [21], Processed 1600/3986 images
# Epoch [21], Processed 1700/3986 images
# Epoch [21], Processed 1800/3986 images
# Epoch [21], Processed 1900/3986 images
# Epoch [21], Processed 2000/3986 images
# Epoch [21], Processed 2100/3986 images
# Epoch [21], Processed 2200/3986 images
# Epoch [21], Processed 2300/3986 images
# Epoch [21], Processed 2400/3986 images
# Epoch [21], Processed 2500/3986 images
# Epoch [21], Processed 2600/3986 images
# Epoch [21], Processed 2700/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [21], Processed 2800/3986 images
# Epoch [21], Processed 2900/3986 images
# Epoch [21], Processed 3000/3986 images
# Epoch [21], Processed 3100/3986 images
# Epoch [21], Processed 3200/3986 images
# Epoch [21], Processed 3300/3986 images
# Epoch [21], Processed 3400/3986 images
# Epoch [21], Processed 3500/3986 images
# Epoch [21], Processed 3600/3986 images
# Epoch [21], Processed 3700/3986 images
# Epoch [21], Processed 3800/3986 images
# Epoch [21], Processed 3900/3986 images
# Epoch [21], Training Loss: 4.328607236370519
# Epoch [21], Validation Loss: 4.8278393225669864
# Epoch [21], Validation Class Loss: 0.4837962416410446
# Epoch [21], Validation Box Loss: 0.2820556529911701
# Epoch [21], Validation Mask Loss: 0.5954634130001069
# mAP@50: 0.03301658977901572, Precision: 0.03301658977901572, Recall: 0.11803784368979955
# Saved checkpoint for Epoch 21 at /kaggle/working/model_epoch_21.pth
# Epoch [22], Processed 100/3986 images
# Epoch [22], Processed 200/3986 images
# Epoch [22], Processed 300/3986 images
# Epoch [22], Processed 400/3986 images
# Epoch [22], Processed 500/3986 images
# Epoch [22], Processed 600/3986 images
# Epoch [22], Processed 700/3986 images
# Epoch [22], Processed 800/3986 images
# Epoch [22], Processed 900/3986 images
# Epoch [22], Processed 1000/3986 images
# Epoch [22], Processed 1100/3986 images
# Epoch [22], Processed 1200/3986 images
# Epoch [22], Processed 1300/3986 images
# Epoch [22], Processed 1400/3986 images
# Epoch [22], Processed 1500/3986 images
# Epoch [22], Processed 1600/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [22], Processed 1700/3986 images
# Epoch [22], Processed 1800/3986 images
# Epoch [22], Processed 1900/3986 images
# Epoch [22], Processed 2000/3986 images
# Epoch [22], Processed 2100/3986 images
# Epoch [22], Processed 2200/3986 images
# Epoch [22], Processed 2300/3986 images
# Epoch [22], Processed 2400/3986 images
# Epoch [22], Processed 2500/3986 images
# Epoch [22], Processed 2600/3986 images
# Epoch [22], Processed 2700/3986 images
# Epoch [22], Processed 2800/3986 images
# Epoch [22], Processed 2900/3986 images
# Epoch [22], Processed 3000/3986 images
# Epoch [22], Processed 3100/3986 images
# Epoch [22], Processed 3200/3986 images
# Epoch [22], Processed 3300/3986 images
# Epoch [22], Processed 3400/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [22], Processed 3500/3986 images
# Epoch [22], Processed 3600/3986 images
# Epoch [22], Processed 3700/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [22], Processed 3800/3986 images
# Epoch [22], Processed 3900/3986 images
# Epoch [22], Training Loss: 4.359056512953166
# Epoch [22], Validation Loss: 4.464659794092178
# Epoch [22], Validation Class Loss: 0.4980179404616356
# Epoch [22], Validation Box Loss: 0.2829919366062386
# Epoch [22], Validation Mask Loss: 0.5886488516330719
# mAP@50: 0.027417278431657248, Precision: 0.027417278431657248, Recall: 0.1275604591552435
# Saved checkpoint for Epoch 22 at /kaggle/working/model_epoch_22.pth
# Epoch [23], Processed 100/3986 images
# Epoch [23], Processed 200/3986 images
# Epoch [23], Processed 300/3986 images
# Epoch [23], Processed 400/3986 images
# Epoch [23], Processed 500/3986 images
# Epoch [23], Processed 600/3986 images
# Epoch [23], Processed 700/3986 images
# Epoch [23], Processed 800/3986 images
# Epoch [23], Processed 900/3986 images
# Epoch [23], Processed 1000/3986 images
# Epoch [23], Processed 1100/3986 images
# Epoch [23], Processed 1200/3986 images
# Epoch [23], Processed 1300/3986 images
# Epoch [23], Processed 1400/3986 images
# Epoch [23], Processed 1500/3986 images
# Skipping invalid box: [0, 130, 0, 136]
# Epoch [23], Processed 1600/3986 images
# Skipping invalid box: [99, 73, 99, 74]
# Epoch [23], Processed 1700/3986 images
# Epoch [23], Processed 1800/3986 images
# Epoch [23], Processed 1900/3986 images
# Epoch [23], Processed 2000/3986 images
# Epoch [23], Processed 2100/3986 images
# Epoch [23], Processed 2200/3986 images
# Epoch [23], Processed 2300/3986 images
# Epoch [23], Processed 2400/3986 images
# Epoch [23], Processed 2500/3986 images
# Epoch [23], Processed 2600/3986 images
# Epoch [23], Processed 2700/3986 images
# Epoch [23], Processed 2800/3986 images
# Skipping invalid box: [334, 309, 334, 309]
# Epoch [23], Processed 2900/3986 images
# Epoch [23], Processed 3000/3986 images
# Epoch [23], Processed 3100/3986 images
# Epoch [23], Processed 3200/3986 images
# Epoch [23], Processed 3300/3986 images
# Epoch [23], Processed 3400/3986 images
# Epoch [23], Processed 3500/3986 images
# Epoch [23], Processed 3600/3986 images
# Epoch [23], Processed 3700/3986 images
# Epoch [23], Processed 3800/3986 images
# Epoch [23], Processed 3900/3986 images
# Epoch [23], Training Loss: 4.140051683906089
# Epoch [23], Validation Loss: 4.49292804479599
# Epoch [23], Validation Class Loss: 0.4857085777819157
# Epoch [23], Validation Box Loss: 0.2835726696469064
# Epoch [23], Validation Mask Loss: 0.5842637804746628
# mAP@50: 0.035169807704448046, Precision: 0.035169807704448046, Recall: 0.13358010539555173
# Saved checkpoint for Epoch 23 at /kaggle/working/model_epoch_23.pth
# Early stopping at epoch 23. Best Validation Loss: 4.445013014793396
# Loss history saved to loss_history.csv
